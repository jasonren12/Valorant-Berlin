# %%
import requests
from lxml import etree, html
from io import StringIO
from collections import defaultdict

# %%
URL = "https://www.vlr.gg/29391/sentinels-vs-rise-champions-tour-north-america-stage-3-challengers-playoffs-ubqf/?game=all&tab=overview"
page = requests.get(URL)
root = html.fromstring(page.content)

# %%
def print_node(node):
    print(node.tag, node.attrib)
    txt = node.text
    if txt:
        print(txt.strip())
    print()
    for child in node:
        print_node(child)

print_node(root)
# Out:
# html {'lang': 'en'}
#
#
# head {}
#
#
# title {}
# Sentinels vs. Rise | Champions Tour North America Stage 3: Challengers Playoffs | Main Event | Valorant match | VLR.gg
#
# meta {'name': 'description', 'content': 'Stats, score, streams, and VODs from Sentinels vs. Rise - Upper Quarterfinals match of Champions Tour North America Stage 3: Challengers Playoffs Valorant event'}
#
# meta {'charset': 'utf-8'}
#
# meta {'property': 'og:title', 'content': 'Sentinels vs. Rise | Champions Tour North America Stage 3: Challengers Playoffs | Main Event | Valorant match | VLR.gg'}
#
# meta {'property': 'og:site_name', 'content': 'VLR.gg'}
#
# meta {'property': 'og:description', 'content': 'Stats, score, streams, and VODs from Sentinels vs. Rise - Upper Quarterfinals match of Champions Tour North America Stage 3: Challengers Playoffs Valorant event'}
#
# meta {'property': 'og:image', 'content': '/img/vlr/favicon.png'}
#
# meta {'name': 'twitter:card', 'content': 'summary'}
#
# ...

# %%
def find_nodes(node_names, root):
    out = []
    q = [root]
    while q:
        node = q.pop(0)
        node_class = node.attrib.get("class", None)
        if node_class and node_class in node_names:
            print("Found node")
            out.append(node)

        for child in node:
            q.append(child)
            
    return out

# find_nodes(["vm-stats-game ", "vm-stats-game mod-active"])

# %%
def print_single_node(node, level = None):
    if level:
        print(f"Level {level}")
    print(f"Tag: {node.tag}, Attribs: {node.attrib}")
    if node.text:
        print(f"Text: {node.text.strip()}")
    print()

def iterate_from_dfs(node):
    print_single_node(node)
    for child in node:
        iterate_from(child)
        
def iterate_from_bfs(node, print_nodes=False):
    track = [(node, 0)]
    q = [(node, 0)]
    while q:
        next_node, level = q.pop(0)
        if print_nodes:
            print_single_node(next_node, level)
        for child in next_node:
            q.append((child, level + 1))
            track.append((child, level + 1))
            
    return track

# %%
stat_nodes = find_nodes(["vm-stats-game ", "vm-stats-game mod-active"])

def get_player_map_stats(container_node):

    nodes = iterate_from_bfs(container_node, False)

    table_nodes = [x[0] for x in nodes if x[1] == 7]
    stat_nodes = [x for x in table_nodes if "stats-sq" in x.attrib.get("class", "")]

    assists = []
    assist_idxs = range(3, 103, 10)
    for i in assist_idxs:
        assists.append(int(stat_nodes[i].text.strip()))

    acss = []
    acs_idxs = range(0, 100, 10)
    for i in acs_idxs:
        acss.append(stat_nodes[i].text.strip())

    player_nodes = [x[0] for x in nodes if x[1] == 9]

    map_player_order = []
    player_info = defaultdict(dict)
    for i in range(0, 30, 3):
        player = player_nodes[i].text.strip()
        team = player_nodes[i+1].text.strip()
        agent = player_nodes[i+2].attrib["title"]
        map_player_order.append(player)
        player_info[player]["team"] = team
        player_info[player]["agent"] = agent
        player_num = i // 3
        player_info[player]["assists"] = assists[player_num]
        player_info[player]["acs"] = acss[player_num]


    return player_info

get_player_map_stats(stat_nodes[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xk/qgnjm7ss4835hy49gtn06sxr0000gn/T/ipykernel_21735/3961191754.py in <module>
# ----> 1 stat_nodes = find_nodes(["vm-stats-game ", "vm-stats-game mod-active"])
#       2
#       3 def get_player_map_stats(container_node):
#       4
#       5     nodes = iterate_from_bfs(container_node, False)
#
# TypeError: find_nodes() missing 1 required positional argument: 'root'

# %%
def get_meta(container_node):
    nodes = iterate_from_bfs(container_node, False)
    meta_nodes = [x[0] for x in nodes if x[1] == 4]

    map_name = meta_nodes[3].text.strip()
    team1 = meta_nodes[0].text.strip()
    team2 = meta_nodes[4].text.strip()

    score_nodes = [x[0] for x in nodes if x[1] == 3 and "score" in x[0].attrib.get("class", "")]
    team1_rounds = int(score_nodes[0].text.strip())
    team2_rounds = int(score_nodes[1].text.strip())
    
    player_nodes = [x[0] for x in nodes if x[1] == 9]
    team1_abbrev = player_nodes[1].text.strip()
    team2_abbrev = player_nodes[16].text.strip()
    
    meta = {
        "map_name": map_name,
        "team1": team1,
        "team2": team2,
        "team1_abbrev": team1_abbrev,
        "team2_abbrev": team2_abbrev,
        "team1_rounds": team1_rounds,
        "team2_rounds": team2_rounds
    }
    
    return meta

get_meta(stat_nodes[0])

# %%
def get_kds(kd_container_node):
    
    nodes = iterate_from_bfs(kd_container_node, False)
    stat_nodes = [x[0] for x in nodes if x[1] == 6]

    team_nodes = [x[0] for x in nodes if x[1] == 7]
    team2 = team_nodes[0].text.strip()
    team1 = team_nodes[5].text.strip()
    
    team1_names = []
    team2_names = [] 
    
    for i in range(1, 11, 2):
        team2_names.append(stat_nodes[i].text.strip())

    for i in range(11, 80, 17):
        team1_names.append(stat_nodes[i].text.strip())

    start = 11
    team1_idx = 0
    team2_idx = 0
    kds = {t1: {t2: None for t2 in team2_names} for t1 in team1_names}
    while team1_idx < 5:
        # 10 for team2 names, 2 for initial team1 name in row
        start = 10 + team1_idx * 17 + 2
        for i in range(start, start + 15, 3):        
            team2_idx = (i - start) // 3
            team1_player = team1_names[team1_idx]
            team2_player = team2_names[team2_idx]
            
            try:
                kills = int(stat_nodes[i].text.strip())
            except ValueError as e:
                kills = 0
            try:
                deaths = int(stat_nodes[i+1].text.strip())
            except ValueError as e:
                deaths = 0

            kds[team1_player][team2_player] = {
                "kills": kills, 
                "deaths": deaths
            }

        team1_idx += 1

    return kds

# %%
def get_date(overview_root):
    date_node = find_nodes(["match-header-date"], overview_root)[0]
    date_nodes = iterate_from_bfs(date_node, False)
    game_date = date_nodes[1][0].attrib["data-utc-ts"]
    return game_date

# %%
class Player():
    def __init__(self, name, team):
        self.team = team
        self.name = name
        
    def __str__(self):
        return f"{self.team} {self.name}"
    
class Game():
    def __init__(
        self,
        game_date,
        map_name,
        team_info,
        team1_rounds,
        team2_rounds,
        agents,
        assists,
        acss,
        kds
    ):
        self.map_name = map_name
        self.team_info = team_info
        self.team1_rounds = team1_rounds
        self.team2_rounds = team2_rounds
        
        self.agents = agents
        self.assists = assists
        self.acss = acss
        self.kds = kds
        
    def __str__(self):
        return f"{self.team_info['team1']} vs. {self.team_info['team2']} on {self.map_name}"

# %%
base_url = "https://www.vlr.gg/25200/xset-vs-sentinels-champions-tour-north-america-stage-3-challengers-1-gf/?game=all&tab="
overview_url = base_url + "overview"
overview_page = requests.get(overview_url)
overview_root = html.fromstring(overview_page.content)
overview_container_nodes = find_nodes(["vm-stats-game "], overview_root)

performance_url = base_url + "performance"
performance_page = requests.get(performance_url)
performance_root = html.fromstring(performance_page.content)
performance_container_nodes = find_nodes(["vm-stats-game "], performance_root)

game_date = get_date(overview_root)
for onode, pnode in zip(overview_container_nodes, performance_container_nodes):
    
    meta = get_meta(onode)
    player_map_stats = get_player_map_stats(onode)
    kds = get_kds(pnode)
    
    team1_abbrev = meta["team1_abbrev"]
    team2_abbrev = meta["team2_abbrev"]
    team1_players = [player for player, info in player_map_stats.items() if info["team"] == team1_abbrev]
    team2_players = [player for player, info in player_map_stats.items() if info["team"] == team2_abbrev]
    
    assists = {player: player_info["assists"] for player, player_info in player_map_stats.items()}
    acss = {player: player_info["acs"] for player, player_info in player_map_stats.items()}
    agents = {player: player_info["agent"] for player, player_info in player_map_stats.items()}
    
    game = Game(
        game_date = game_date,
        map_name = meta["map_name"],
        team_info = {
            "team1": meta["team1"],
            "team2": meta["team2"],
            "team1_abbrev": team1_abbrev,
            "team2_abbrev": team2_abbrev,
            "team1_players": team1_players,
            "team2_players": team2_players,
        },
        
        team1_rounds = meta["team1_rounds"],
        team2_rounds = meta["team2_rounds"],
        
        agents = agents,
        assists = assists,
        acss = acss,
        kds = kds   
    )
    print(meta)
    print(team1_players)
    print(team2_players)
    print(player_map_stats)
    print(kds)
    print()
    
    print(game)
# Out:
# Found node
# Found node
# Found node
# Found node
# Found node
# Found node
# Found node
# Found node
# Found node
# Found node
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xk/qgnjm7ss4835hy49gtn06sxr0000gn/T/ipykernel_21735/1632020885.py in <module>
#      13 for onode, pnode in zip(overview_container_nodes, performance_container_nodes):
#      14
# ---> 15     meta = get_meta(onode)
#      16     player_map_stats = get_player_map_stats(onode)
#      17     kds = get_kds(pnode)
#
# NameError: name 'get_meta' is not defined

# %%
# Out:
# 2021-08-11 15:00:00

# %%
def print_kd_dict(kd):
    for p1, p1_stats in kd.items():
        for p2, stats in p1_stats.items():
            print(f"{p1} vs {p2}: {stats}")

def get_game_stats():
    stat_nodes = find_nodes(["vm-stats-game ", "vm-stats-game mod-active"])

    map_kds = {}
    for map_name, node in zip(["all"] + maps, stat_nodes):
        kds = get_kds(node)
        print(map_name)
        print_kd_dict(kds)
        map_kds[map_name] = kds
        print()
        
game_stats = get_game_stats()
# Out:
# Found node
# Found node
# Found node
# Found node
# all
# ShahZaM vs Shanks: {'kills': 6, 'deaths': 10}
# ShahZaM vs POISED: {'kills': 7, 'deaths': 4}
# ShahZaM vs neptune: {'kills': 13, 'deaths': 6}
# ShahZaM vs supamen: {'kills': 10, 'deaths': 6}
# ShahZaM vs Derrek: {'kills': 6, 'deaths': 5}
# zombs vs Shanks: {'kills': 9, 'deaths': 9}
# zombs vs POISED: {'kills': 5, 'deaths': 4}
# zombs vs neptune: {'kills': 10, 'deaths': 7}
# zombs vs supamen: {'kills': 5, 'deaths': 5}
# zombs vs Derrek: {'kills': 9, 'deaths': 4}
# dapr vs Shanks: {'kills': 8, 'deaths': 6}
# dapr vs POISED: {'kills': 11, 'deaths': 6}
# dapr vs neptune: {'kills': 9, 'deaths': 3}
# dapr vs supamen: {'kills': 9, 'deaths': 6}
# dapr vs Derrek: {'kills': 5, 'deaths': 10}
# TenZ vs Shanks: {'kills': 8, 'deaths': 6}
# TenZ vs POISED: {'kills': 12, 'deaths': 10}
# TenZ vs neptune: {'kills': 8, 'deaths': 6}
# TenZ vs supamen: {'kills': 6, 'deaths': 7}
# TenZ vs Derrek: {'kills': 9, 'deaths': 4}
# ...
